# %%
import pandas as pd
import matplotlib.pyplot as plt

platy = pd.read_csv("platy_2021_02.csv")
plt.hist(platy['plat'], bins=range(30000, 61000, 1000), color='green')

plt.title('Histogram platů')
plt.xlabel('Plat')
plt.ylabel('Počet zaměstnanců')

plt.show()
